# %% [markdown]
# Introduction to opencv & Image Processing

# %%
#pip install opencv.python

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\atlah\OneDrive\Attachments\Desktop\lion.jpg")

# %%
img.shape
# Out:
# (408, 612, 3)

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[241, 247, 254],
#         [241, 247, 254],
#         [241, 247, 254],
#         ...,
#         [240, 246, 253],
#         [240, 246, 253],
#         [240, 246, 253]],
#
#        [[241, 247, 254],
#         [241, 247, 254],
#         [241, 247, 254],
#         ...,
#         [240, 246, 253],
#         [240, 246, 253],
#         [240, 246, 253]],
#
#        [[241, 247, 254],
#         [241, 247, 254],
#         [241, 247, 254],
#         ...,
#         [240, 246, 253],
#         [240, 246, 253],
#         [240, 246, 253]],
#
#        ...,
#
#        [[ 43,  78, 121],
#         [ 44,  78, 121],
#         [ 27,  54,  98],
#         ...,
#         [ 99, 175, 251],
#         [100, 176, 252],
#         [101, 177, 253]],
#
#        [[ 45,  80, 123],
#         [ 43,  77, 120],
#         [ 24,  51,  95],
#         ...,
#         [101, 177, 253],
#         [102, 178, 254],
#         [103, 179, 255]],
#
#        [[ 39,  74, 117],
#         [ 36,  70, 113],
#         [ 16,  43,  87],
# ...

# %%
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[254, 247, 241],
#         [254, 247, 241],
#         [254, 247, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        [[254, 247, 241],
#         [254, 247, 241],
#         [254, 247, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        [[254, 247, 241],
#         [254, 247, 241],
#         [254, 247, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        ...,
#
#        [[121,  78,  43],
#         [121,  78,  44],
#         [ 98,  54,  27],
#         ...,
#         [251, 175,  99],
#         [252, 176, 100],
#         [253, 177, 101]],
#
#        [[123,  80,  45],
#         [120,  77,  43],
#         [ 95,  51,  24],
#         ...,
#         [253, 177, 101],
#         [254, 178, 102],
#         [255, 179, 103]],
#
#        [[117,  74,  39],
#         [113,  70,  36],
#         [ 87,  43,  16],
# ...

# %%
plt.imshow(fix_img)

# %%
img_gray =cv2.imread(r"C:\Users\atlah\OneDrive\Attachments\Desktop\lion.jpg",cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (408, 612)

# %%
img_gray
# Out:
# array([[248, 248, 248, ..., 247, 247, 247],
#        [248, 248, 248, ..., 247, 247, 247],
#        [248, 248, 248, ..., 247, 247, 247],
#        ...,
#        [ 87,  87,  64, ..., 189, 190, 191],
#        [ 89,  86,  61, ..., 191, 192, 193],
#        [ 83,  79,  53, ..., 193, 194, 195]], shape=(408, 612), dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (408, 612, 3)

# %%
fix_img_1=cv2.resize(fix_img,(204,306,))

# %%
fix_img_1.shape
# Out:
# (306, 204, 3)

# %%
w_ratio=0.5
h_ratio=0.5

# %%
fix_img_2=cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
fix_img_2
# Out:
# array([[[254, 247, 241],
#         [254, 247, 241],
#         [254, 247, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        [[254, 247, 241],
#         [254, 247, 241],
#         [254, 247, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        [[254, 247, 241],
#         [254, 247, 241],
#         [254, 247, 241],
#         ...,
#         [253, 246, 240],
#         [253, 246, 240],
#         [253, 246, 240]],
#
#        ...,
#
#        [[113,  70,  36],
#         [ 97,  54,  28],
#         [ 71,  33,   8],
#         ...,
#         [241, 163,  83],
#         [244, 168,  92],
#         [247, 171,  95]],
#
#        [[117,  74,  40],
#         [ 91,  48,  23],
#         [ 67,  29,   5],
#         ...,
#         [244, 168,  88],
#         [249, 173,  97],
#         [251, 175,  99]],
#
#        [[118,  75,  41],
#         [ 88,  45,  19],
#         [ 76,  37,  12],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img3=cv2.flip(fix_img_2, 0)
plt.imshow(img3)

# %%
img3=cv2.flip(fix_img_2, 1)
plt.imshow(img3)

# %%
cv2.imwrite('new genai image.jpg',img3)
# Out:
# True

# %% [markdown]
# without using matplotlib we work imgag with open cv

# %%
import cv2
dhoni=cv2.imread(r"C:\Users\atlah\OneDrive\Attachments\Desktop\dhoni.jpg")
cv2.imshow('dhoni',dhoni)
cv2.waitKey()
# Out:
# 27

# %%
import cv2
dhoni=cv2.imread(r"C:\Users\atlah\OneDrive\Attachments\Desktop\dhoni.jpg")
while True:
    cv2.imshow('dhoni',dhoni)
    if cv2.waitKey(1) & 0xFF ==27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# read video using open cv

# %%
import cv2

cap=cv2.VideoCapture(0)

width=cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height=cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
while True:
    ret, frame=cap.read()
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow('frame', gray)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release() 
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>
